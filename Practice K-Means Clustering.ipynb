# %% [markdown]
# ### Q1

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import pandas as pd

# Read in data without headers
data = np.genfromtxt('FrownyFace.csv', delimiter=',')[1:,1:]
x = data[:,0]
y = data[:,1]

plt.scatter(x, y, marker='o', label='Data Points')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %% [markdown]
# ### Q2

# %%
# Custom initial centroid locations
initial_centroids = np.array([[-2,5], [2,5], [0,-5]])

# Create KMeans object with custom initialization
kmeans = KMeans(n_clusters=3, init=initial_centroids, n_init=1)

# Fit the KMeans model to the data
kmeans.fit(data)

# Get the final centroid positions
centroids = initial_centroids

# Get the cluster assignments for each data point
labels = kmeans.labels_

# Scatter plot of data points with color-coded clusters
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='rainbow', edgecolor='k', s=100, label='Data Points')

# Scatter plot of final centroid positions
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=200, label='Centroids')

# Set labels and legend
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('K-Means Clustering with Custom Initial Centroids')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### Q3

# %%
# Custom initial centroid locations
initial_centroids = np.array([[-3,0], [0,0], [3,0]])

# Create KMeans object with custom initialization
kmeans = KMeans(n_clusters=3, init=initial_centroids, n_init=1)

# Fit the KMeans model to the data
kmeans.fit(data)

# Get the final centroid positions
centroids = initial_centroids

# Get the cluster assignments for each data point
labels = kmeans.labels_

# Scatter plot of data points with color-coded clusters
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='rainbow', edgecolor='k', s=100, label='Data Points')

# Scatter plot of final centroid positions
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=200, label='Centroids')

# Set labels and legend
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('K-Means Clustering with Custom Initial Centroids')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### Q4

# %%
# Custom initial centroid locations
initial_centroids = np.array([[-3,0], [-1,0], [1,0], [3,0]])

# Create KMeans object with custom initialization
kmeans = KMeans(n_clusters=4, init=initial_centroids, n_init=1)

# Fit the KMeans model to the data
kmeans.fit(data)

# Get the final centroid positions
centroids = initial_centroids

# Get the cluster assignments for each data point
labels = kmeans.labels_

# Scatter plot of data points with color-coded clusters
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='rainbow', edgecolor='k', s=100, label='Data Points')

# Scatter plot of final centroid positions
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=200, label='Centroids')

# Set labels and legend
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('K-Means Clustering with Custom Initial Centroids')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### Q5

# %%
# Custom initial centroid locations
initial_centroids = np.array([[-2,5], [2,5], [0,-3], [0,-7]])

# Create KMeans object with custom initialization
kmeans = KMeans(n_clusters=4, init=initial_centroids, n_init=1)

# Fit the KMeans model to the data
kmeans.fit(data)

# Get the final centroid positions
centroids = initial_centroids

# Get the cluster assignments for each data point
labels = kmeans.labels_

# Scatter plot of data points with color-coded clusters
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='rainbow', edgecolor='k', s=100, label='Data Points')

# Scatter plot of final centroid positions
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=200, label='Centroids')

# Set labels and legend
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('K-Means Clustering with Custom Initial Centroids')
plt.legend()

# Show the plot
plt.show()
